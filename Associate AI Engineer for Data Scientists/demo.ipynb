# %%
import numpy as np
d_model = 30
W_q = np.random.randn(d_model, d_model)
print(W_q)
# Out:
# [[-2.84372082e+00  1.25736034e+00 -1.02847208e+00 -1.44721108e-01
#    1.23081986e+00  5.28255559e-01 -6.61280442e-01  4.17869490e-01
#   -9.90585541e-01  1.28154825e-01 -7.42614820e-01 -1.37590842e+00
#    5.33573984e-01 -8.04563589e-01 -2.45076939e-01  2.17825047e-01
#    5.04541848e-01  1.15032196e+00 -9.11730965e-01  1.42785827e+00
#   -5.14412261e-01 -9.76224227e-01 -6.17252661e-01 -3.96053227e-01
#   -5.33491229e-01 -1.64600719e+00 -1.59606639e-01 -4.72192185e-01
#   -7.89743552e-01  5.49440815e-01]
#  [-6.29008418e-01  5.02685540e-01  1.25557979e+00  1.20955995e+00
#    7.22916535e-01 -1.00209689e+00 -6.22242835e-01  4.13176803e-02
#   -1.91172463e+00 -1.16687452e+00 -2.91996654e-01 -8.90893007e-01
#    4.18703615e-01 -1.17679455e-01 -8.49639529e-01  7.18601407e-01
#   -2.42887557e-01 -6.58832933e-02  6.01660112e-01  7.95949535e-01
#    1.83570391e+00  2.10885777e-01  1.76220966e+00 -7.22919088e-02
#   -9.96665343e-01  1.99195017e+00 -2.04998313e+00 -2.96494909e-01
# ...

# %%
import torch
data = range(1, 100)
block_size = 8
batch_size = 4
torch.randint(len(data) - block_size, (batch_size, ))
# Out:
# tensor([21, 65,  6, 10])
