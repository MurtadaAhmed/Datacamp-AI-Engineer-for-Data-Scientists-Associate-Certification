# %%
import pandas as pd

dataset = "datasets/sales_subset.csv"
sales_df = pd.read_csv(dataset)

print(f"Head:\n{sales_df.head()}")
print(f"\nInfo:\n{sales_df.info()}")
print(f"\nShape:\n{sales_df.shape}")
print(f"\nDescribe:\n{sales_df.describe()}")
print(f"\nColumns:\n{sales_df.columns}")
print(f"\nIndex:\n{sales_df.index}")
# Out:
# Head:
#    Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0           0      1    A           1  2010-02-05      24924.50       False
# 1           1      1    A           1  2010-03-05      21827.90       False
# 2           2      1    A           1  2010-04-02      57258.43       False
# 3           3      1    A           1  2010-05-07      17413.94       False
# 4           4      1    A           1  2010-06-04      17558.09       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment
# 0       5.727778              0.679451         8.106
# 1       8.055556              0.693452         8.106
# 2      16.816667              0.718284         7.808
# 3      22.527778              0.748928         7.808
# 4      27.050000              0.714586         7.808
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10774 entries, 0 to 10773
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ...

# %% [markdown]
# # Sorting and subsetting

# %%
import pandas as pd

dataset = "datasets/sales_subset.csv"
sales_df = pd.read_csv(dataset)

sales_df
# Out:
#        Unnamed: 0  store type  department        date  weekly_sales  \
# 0               0      1    A           1  2010-02-05      24924.50
# 1               1      1    A           1  2010-03-05      21827.90
# 2               2      1    A           1  2010-04-02      57258.43
# 3               3      1    A           1  2010-05-07      17413.94
# 4               4      1    A           1  2010-06-04      17558.09
# ...           ...    ...  ...         ...         ...           ...
# 10769       10769     39    A          99  2011-12-09        895.00
# 10770       10770     39    A          99  2012-02-03        350.00
# 10771       10771     39    A          99  2012-06-08        450.00
# 10772       10772     39    A          99  2012-07-13          0.06
# 10773       10773     39    A          99  2012-10-05        915.00
#
#        is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 0           False       5.727778              0.679451         8.106
# ...

# %%
sales_df.sort_values("weekly_sales", ascending=False)
# Out:
#       Unnamed: 0  store type  department        date  weekly_sales  \
# 6201        6201     14    A          92  2010-02-05     293966.05
# 4271        4271     10    B          72  2010-02-05     232558.51
# 4281        4281     10    B          72  2010-12-03     218559.54
# 6202        6202     14    A          92  2010-03-05     214383.07
# 6237        6237     14    A          95  2010-02-05     213042.66
# ...          ...    ...  ...         ...         ...           ...
# 3217        3217      6    A          47  2010-04-30       -698.00
# 4110        4110     10    B          47  2010-03-05       -798.00
# 4115        4115     10    B          47  2010-10-15       -798.00
# 1422        1422      2    A          47  2010-10-15      -1098.00
# 1420        1420      2    A          47  2010-07-30      -1098.00
#
#       is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 6201       False      -2.605556              0.735455         8.992
# ...

# %%
sales_df["weekly_sales"]
# Out:
# 0        24924.50
# 1        21827.90
# 2        57258.43
# 3        17413.94
# 4        17558.09
#            ...
# 10769      895.00
# 10770      350.00
# 10771      450.00
# 10772        0.06
# 10773      915.00
# Name: weekly_sales, Length: 10774, dtype: float64

# %%
sales_df[["weekly_sales", "department"]].sort_values("weekly_sales", ascending=False)
# Out:
#       weekly_sales  department
# 6201     293966.05          92
# 4271     232558.51          72
# 4281     218559.54          72
# 6202     214383.07          92
# 6237     213042.66          95
# ...            ...         ...
# 3217       -698.00          47
# 4110       -798.00          47
# 4115       -798.00          47
# 1422      -1098.00          47
# 1420      -1098.00          47
#
# [10774 rows x 2 columns]

# %%
sales_df[sales_df["is_holiday"]].sort_values("weekly_sales", ascending=False)
# Out:
#        Unnamed: 0  store type  department        date  weekly_sales  \
# 9003         9003     27    A          99  2011-11-25       5350.00
# 1793         1793      2    A          99  2011-11-25       2850.00
# 896           896      1    A          99  2011-11-25       2400.00
# 4295         4295     10    B          77  2011-11-25       1590.00
# 3588         3588      6    A          99  2011-11-25       1550.00
# 1587         1587      2    A          77  2011-11-25       1431.00
# 691           691      1    A          77  2011-11-25       1431.00
# 5197         5197     13    A          77  2011-11-25       1272.00
# 3383         3383      6    A          77  2011-11-25       1272.00
# 7901         7901     20    A          77  2011-11-25       1272.00
# 2487         2487      4    A          77  2011-11-25        954.00
# 2320         2320      4    A          47  2010-09-10        898.00
# 9687         9687     31    A          77  2011-11-25        795.00
# ...

# %%
is_a_or_b = sales_df["type"].isin(["A", "B"])
sales_df[is_a_or_b].sort_values("weekly_sales", ascending=False)
# Out:
#       Unnamed: 0  store type  department        date  weekly_sales  \
# 6201        6201     14    A          92  2010-02-05     293966.05
# 4271        4271     10    B          72  2010-02-05     232558.51
# 4281        4281     10    B          72  2010-12-03     218559.54
# 6202        6202     14    A          92  2010-03-05     214383.07
# 6237        6237     14    A          95  2010-02-05     213042.66
# ...          ...    ...  ...         ...         ...           ...
# 3217        3217      6    A          47  2010-04-30       -698.00
# 4110        4110     10    B          47  2010-03-05       -798.00
# 4115        4115     10    B          47  2010-10-15       -798.00
# 1422        1422      2    A          47  2010-10-15      -1098.00
# 1420        1420      2    A          47  2010-07-30      -1098.00
#
#       is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 6201       False      -2.605556              0.735455         8.992
# ...

# %% [markdown]
# # new columns

# %%
sales_df["example_new_column"] = sales_df["department"] * 10
sales_df
# Out:
#        Unnamed: 0  store type  department        date  weekly_sales  \
# 0               0      1    A           1  2010-02-05      24924.50
# 1               1      1    A           1  2010-03-05      21827.90
# 2               2      1    A           1  2010-04-02      57258.43
# 3               3      1    A           1  2010-05-07      17413.94
# 4               4      1    A           1  2010-06-04      17558.09
# ...           ...    ...  ...         ...         ...           ...
# 10769       10769     39    A          99  2011-12-09        895.00
# 10770       10770     39    A          99  2012-02-03        350.00
# 10771       10771     39    A          99  2012-06-08        450.00
# 10772       10772     39    A          99  2012-07-13          0.06
# 10773       10773     39    A          99  2012-10-05        915.00
#
#        is_holiday  temperature_c  fuel_price_usd_per_l  unemployment  \
# 0           False       5.727778              0.679451         8.106
# ...
